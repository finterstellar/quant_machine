# %%
import json
import requests

url = "https://kapi.kakao.com/v2/api/talk/memo/default/send"

# 사용자 토큰
headers = {
    'Host': 'kapi.kakao.com',
    "Authorization": "Bearer " + '325a9197f1501eb29c1e5261a3183cde',
}


data = {
    "template_object" : json.dumps({ "object_type" : "text",
                                     "text" : "Hello, world!",
                                     "link" : {
                                                 "web_url" : "https://finterstellar.com"
                                              }
    })
}

response = requests.post(url, headers=headers, data=data)
print(response.status_code)
if response.json().get('result_code') == 0:
    print('메시지를 성공적으로 보냈습니다.')
else:
    print('메시지를 성공적으로 보내지 못했습니다. 오류메시지 : ' + str(response.json()))
# Out:
# 401
# 메시지를 성공적으로 보내지 못했습니다. 오류메시지 : {'msg': 'this access token does not exist', 'code': -401}

# %%
# !git clone https://github.com/quant4junior/algoTrade.git

# %%
# !ls

# %%
#@title
