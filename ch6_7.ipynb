# %%
pip install finterstellar
# Out:
# Collecting finterstellar
#   Downloading https://files.pythonhosted.org/packages/78/50/ee98e50e817e58105d1d2ad137f30900e2d6feca703e7860a64998adfa21/finterstellar-0.1.6-py3-none-any.whl
# Installing collected packages: finterstellar
# Successfully installed finterstellar-0.1.6

# %%
import finterstellar as fs

# %%
df = fs.fn_single(otp='OTP', symbol='GS', window='T')

# %%
df['Gross Margin'] = df['Gross Profit'] / df['Revenue']
df['Operating Margin'] = df['Operating Income'] / df['Revenue']
df['Profit Margin'] = df['Net Income'] / df['Revenue']

# %%
fs.draw_chart(df, left=['Gross Margin', 'Operating Margin', 'Profit Margin'], right='Price')

# %%
df = fs.fn_single(otp='OTP', symbol='GOOGL', window='T')
df['Gross Margin'] = df['Gross Profit'] / df['Revenue']
df['Operating Margin'] = df['Operating Income'] / df['Revenue']
df['Profit Margin'] = df['Net Income'] / df['Revenue']
fs.draw_chart(df, left=['Gross Margin', 'Operating Margin', 'Profit Margin'], right='Price')

# %%
df = fs.fn_single(otp='OTP', symbol='F', window='T')
df['Gross Margin'] = df['Gross Profit'] / df['Revenue']
df['Operating Margin'] = df['Operating Income'] / df['Revenue']
df['Profit Margin'] = df['Net Income'] / df['Revenue']
fs.draw_chart(df, left=['Gross Margin', 'Operating Margin', 'Profit Margin'], right='Price')

# %%
df = fs.fn_single(otp='OTP', symbol='COST', window='T')
df['Gross Margin'] = df['Gross Profit'] / df['Revenue']
df['Operating Margin'] = df['Operating Income'] / df['Revenue']
df['Profit Margin'] = df['Net Income'] / df['Revenue']
fs.draw_chart(df, left=['Gross Margin', 'Operating Margin', 'Profit Margin'], right='Price')

# %%
df = fs.fn_single(otp='OTP', symbol='JWN', window='T')
df['Gross Margin'] = df['Gross Profit'] / df['Revenue']
df['Operating Margin'] = df['Operating Income'] / df['Revenue']
df['Profit Margin'] = df['Net Income'] / df['Revenue']
fs.draw_chart(df, left=['Gross Margin', 'Operating Margin', 'Profit Margin'], right='Price')

# %%
# Gross Margin
terms = fs.set_terms(trade_start='2011Q1', trade_end='2021Q1')
data = {}
for t in terms:
    data[t] = fs.fn_consolidated(otp='OTP', term=t)
s = {}
signal = {}
for t in terms:
    data[t]['Gross Margin'] = data[t]['Gross Profit'] / data[t]['Revenue'] * 100
    data[t]['Operating Margin'] = data[t]['Operating Income'] / data[t]['Revenue'] * 100
    data[t]['Profit Margin'] = data[t]['Net Income'] / data[t]['Revenue'] * 100
    s[t] = fs.fn_filter(data[t], by='Gross Margin', floor=0, n=30, asc=False)
    signal[t] = list(s[t].index)
df = fs.backtest(signal=signal, data=data, m=3, cost=.001)
fs.draw_return(df)
# Out:
# 2010Q4...OK
# 2011Q1...OK
# 2011Q2...OK
# 2011Q3...OK
# 2011Q4...OK
# 2012Q1...OK
# 2012Q2...OK
# 2012Q3...OK
# 2012Q4...OK
# 2013Q1...OK
# 2013Q2...OK
# 2013Q3...OK
# 2013Q4...OK
# 2014Q1...OK
# 2014Q2...OK
# 2014Q3...OK
# 2014Q4...OK
# 2015Q1...OK
# 2015Q2...OK
# 2015Q3...OK
# 2015Q4...OK
# 2016Q1...OK
# 2016Q2...OK
# 2016Q3...OK
# 2016Q4...OK
# 2017Q1...OK
# 2017Q2...OK
# 2017Q3...OK
# 2017Q4...OK
# 2018Q1...OK
# 2018Q2...OK
# 2018Q3...OK
# 2018Q4...OK
# 2019Q1...OK
# 2019Q2...OK
# 2019Q3...OK
# 2019Q4...OK
# 2020Q1...OK
# 2020Q2...OK
# 2020Q3...OK
# 2020Q4...OK
# CAGR: 16.90%
# Accumulated return: 377.24%
# Investment period: 10.0yrs
# Sharpe ratio: 1.25
# MDD: -30.14%

# %%
sector_info = fs.sector_info(data['2020Q3'])
sector_info
# Out:
# sector
# Basic Materials           [Aluminum, Gold, Silver, Specialty Chemicals, ...
# Communication Services    [Advertising Agencies, Entertainment, Broadcas...
# Consumer Cyclical         [Specialty Retail, Auto & Truck Dealerships, G...
# Consumer Defensive        [Beverages—Brewers, Grocery Stores, Farm Produ...
# Energy                    [Oil & Gas Midstream, Oil & Gas E&P, Oil & Gas...
# Financial Services        [Banks—Regional, Insurance—Diversified, Credit...
# Healthcare                [Diagnostics & Research, Drug Manufacturers—Ge...
# Industrials               [Airlines, Building Products & Equipment, Airp...
# Other                                                               [Other]
# Real Estate               [Reit—Mortgage, Reit—Diversified, Reit—Residen...
# Technology                [Semiconductors, Consumer Electronics, Softwar...
# Utilities                 [Utilities—Regulated Electric, Utilities—Diver...
# Name: industry, dtype: object

# %%
print(fs.sector_filter(df=data['2020Q4'], sector=['Technology']))
# Out:
#           term    Revenue       COGS  Gross Profit      SG&A  \
# symbol
# AAOI    2020Q4     234.62     184.08         50.54     55.99
# AAPL    2020Q4 294,135.00 180,068.00    114,067.00 20,350.00
# ACIW    2020Q4   1,294.32     622.46        671.86    256.04
# ACLS    2020Q4     474.56     275.98        198.58     78.71
# ACMR    2020Q4     156.62      87.03         69.60     28.99
# ...        ...        ...        ...           ...       ...
# ZI      2020Q4     476.20      84.20        392.00    247.70
# ZIXI    2020Q4     218.48     112.76        105.72     78.34
# ZM      2020Q4   1,957.13     587.25      1,369.88    823.22
# ZS      2020Q4     480.26     107.90        372.36    397.32
# ZUO     2020Q4     296.53     132.78        163.74    166.79
#
#         Operating Income  Net Income   EPS    EBITDA      EBIT  ...  Price  \
# symbol                                                          ...
# AAOI              -48.84      -58.45 -2.67    -23.21    -48.84  ...   8.51
# AAPL           74,253.00   63,930.00  3.75 85,159.00 74,253.00  ... 132.69
# ACIW              144.74       72.66  0.62    313.31    144.74  ...  38.43
# ACLS               58.04       49.98  1.50     67.98     58.04  ...  29.12
# ACMR               21.49       18.78  1.03     22.55     21.49  ...  81.25
# ...                  ...         ...   ...       ...       ...  ...    ...
# ZI                 37.10      -15.00 -0.10    116.90     37.10  ...  48.23
# ZIXI                4.56      -15.45 -0.29     38.24      4.56  ...   8.63
# ZM                414.28      425.04  1.52    520.99    414.28  ... 337.32
# ZS               -138.35     -153.05 -1.17    -68.28   -138.35  ... 199.71
# ZUO               -79.67      -78.14 -0.67    -54.04    -79.67  ...  13.93
#
#         Price_M1  Price_M2  Price_M3                                   name  \
# symbol
# AAOI       11.01      9.32      8.36            Applied Optoelectronics Inc
# AAPL      131.96    121.26    122.15                              Apple Inc
# ACIW       38.39     38.26     38.05                      ACI Worldwide Inc
# ACLS       34.24     36.87     41.09               Axcelis Technologies Inc
# ACMR       90.00     97.16     80.79               ACM Research Inc Class A
# ...          ...       ...       ...                                    ...
# ZI         48.01     52.42     48.90      ZoomInfo Technologies Inc Class A
# ZIXI        8.15      7.38      7.55                               Zix Corp
# ZM        372.07    373.61    321.29  Zoom Video Communications Inc Class A
# ZS        199.70    205.03    171.67                            Zscaler Inc
# ZUO        14.75     14.93     14.80                      Zuora Inc Class A
#
#                      name_kr      sector                             industry  \
# symbol
# AAOI          어플라이드 옵토일렉트로닉스  Technology                       Semiconductors
# AAPL                      애플  Technology                 Consumer Electronics
# ACIW               ACI 월드와이드  Technology              Software—Infrastructure
# ACLS             액셀리스 테크놀로지스  Technology  Semiconductor Equipment & Materials
# ACMR         ACM 리서치 Class A  Technology  Semiconductor Equipment & Materials
# ...                      ...         ...                                  ...
# ZI                 줌인포 테크놀로지  Technology                 Software—Application
# ZIXI                      직스  Technology              Software—Infrastructure
# ZM      줌 비디오 커뮤니케이션 Class A  Technology                 Software—Application
# ZS                     지스케일러  Technology              Software—Infrastructure
# ZUO              주오라 Class A  Technology              Software—Infrastructure
#
#         avg_volume  Gross Margin
# symbol
# AAOI        638400         21.54
# AAPL      99116600         38.78
# ACIW        608600         51.91
# ACLS        137100         41.85
# ACMR        286900         44.44
# ...            ...           ...
# ZI         2136100         82.32
# ZIXI        331700         48.39
# ZM         6530400         69.99
# ZS         1469600         77.53
# ZUO        1354700         55.22
#
# [475 rows x 39 columns]

# %%
for t in terms:
    data[t]['Gross Margin'] = data[t]['Gross Profit'] / data[t]['Revenue'] * 100
    data[t]['Operating Margin'] = data[t]['Operating Income'] / data[t]['Revenue'] * 100
    data[t]['Profit Margin'] = data[t]['Net Income'] / data[t]['Revenue'] * 100

# %%
filtered = fs.sector_filter(df=data['2020Q4'], sector=['Technology'])
print(filtered[['sector','Gross Margin','Operating Margin','Profit Margin']])
# Out:
#             sector  Gross Margin  Operating Margin  Profit Margin
# symbol
# AAOI    Technology         21.54            -20.82         -24.91
# AAPL    Technology         38.78             25.24          21.73
# ACIW    Technology         51.91             11.18           5.61
# ACLS    Technology         41.85             12.23          10.53
# ACMR    Technology         44.44             13.72          11.99
# ...            ...           ...               ...            ...
# ZI      Technology         82.32              7.79          -3.15
# ZIXI    Technology         48.39              2.09          -7.07
# ZM      Technology         69.99             21.17          21.72
# ZS      Technology         77.53            -28.81         -31.87
# ZUO     Technology         55.22            -26.87         -26.35
#
# [475 rows x 4 columns]

# %%
# Gross Margin
terms = fs.set_terms(trade_start='2011Q1', trade_end='2021Q1')
data = {}
for t in terms:
    data[t] = fs.fn_consolidated(otp='OTP', term=t)
s = {}
signal = {}
for t in terms:
    data[t]['Gross Margin'] = data[t]['Gross Profit'] / data[t]['Revenue'] * 100  
    s[t] = fs.sector_filter(df=data[t], sector=['Technology'])
    s[t] = fs.fn_filter(s[t], by='Gross Margin', floor=0, n=30, asc=False)
    signal[t] = list(s[t].index)
df = fs.backtest(signal=signal, data=data, m=3, cost=.001)
fs.draw_return(df)
# Out:
# 2010Q4...OK
# 2011Q1...OK
# 2011Q2...OK
# 2011Q3...OK
# 2011Q4...OK
# 2012Q1...OK
# 2012Q2...OK
# 2012Q3...OK
# 2012Q4...OK
# 2013Q1...OK
# 2013Q2...OK
# 2013Q3...OK
# 2013Q4...OK
# 2014Q1...OK
# 2014Q2...OK
# 2014Q3...OK
# 2014Q4...OK
# 2015Q1...OK
# 2015Q2...OK
# 2015Q3...OK
# 2015Q4...OK
# 2016Q1...OK
# 2016Q2...OK
# 2016Q3...OK
# 2016Q4...OK
# 2017Q1...OK
# 2017Q2...OK
# 2017Q3...OK
# 2017Q4...OK
# 2018Q1...OK
# 2018Q2...OK
# 2018Q3...OK
# 2018Q4...OK
# 2019Q1...OK
# 2019Q2...OK
# 2019Q3...OK
# 2019Q4...OK
# 2020Q1...OK
# 2020Q2...OK
# 2020Q3...OK
# 2020Q4...OK
# CAGR: 17.01%
# Accumulated return: 381.71%
# Investment period: 10.0yrs
# Sharpe ratio: 1.68
# MDD: -19.53%

# %%
fs.draw_return(df, bm='QQQ')

# %%
# Operating Margin
# terms = fs.set_terms(trade_start='2011Q1', trade_end='2021Q1')
# data = {}
# for t in terms:
#     data[t] = fs.fn_consolidated(otp='OTP', term=t)
s = {}
signal = {}
for t in terms:
    data[t]['Operating Margin'] = data[t]['Operating Income'] / data[t]['Revenue'] * 100
    s[t] = fs.sector_filter(df=data[t], sector=['Technology'])
    s[t] = fs.fn_filter(s[t], by='Operating Margin', floor=0, n=30, asc=False)
    signal[t] = list(s[t].index)
df = fs.backtest(signal=signal, data=data, m=3, cost=.001)
fs.draw_return(df, bm='QQQ')
# Out:
# CAGR: 14.78%
# Accumulated return: 297.24%
# Investment period: 10.0yrs
# Sharpe ratio: 1.38
# MDD: -23.33%

# %%
# Net Profit Margin
# terms = fs.set_terms(trade_start='2011Q1', trade_end='2021Q1')
# data = {}
# for t in terms:
#     data[t] = fs.fn_consolidated(otp='OTP', term=t)
s = {}
signal = {}
for t in terms:
    data[t]['Profit Margin'] = data[t]['Net Income'] / data[t]['Revenue'] * 100
    s[t] = fs.sector_filter(df=data[t], sector=['Technology'])
    s[t] = fs.fn_filter(s[t], by='Profit Margin', floor=0, n=30, asc=False)
    signal[t] = list(s[t].index)
df = fs.backtest(signal=signal, data=data, m=3, cost=.001)
fs.draw_return(df, bm='QQQ')
# Out:
# CAGR: 16.03%
# Accumulated return: 342.72%
# Investment period: 10.0yrs
# Sharpe ratio: 1.59
# MDD: -22.26%
