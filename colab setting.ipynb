# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
import os
os.chdir('../My Drive/colab')

# %%
# !ls
# Out:
# sample_data

# %%
from fs import Common
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-59aa6ade1fd9> in <module>()
# ----> 1 from fs import Common
#
# ModuleNotFoundError: No module named 'fs'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
Common.days_before('2020-09-19', 3)
# Out:
# Timestamp('2020-09-16 00:00:00')
